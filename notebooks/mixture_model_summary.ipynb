# %% [markdown]
# ### Contrast low and high concentration parameter:

# %% [markdown]
#                             (a)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
#                             (b)
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Reconstructed parameters vs. ground truth for inference/sampling on the generative model with VI and HMC, compared to N-FINDR

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![vi_scatter.png](attachment:vi_scatter.png)

# %% [markdown]
# ![nfindr_scatter.png](attachment:nfindr_scatter.png)

# %% [markdown]
# ![mcmc_scatter.png](attachment:mcmc_scatter.png)

# %% [markdown]
# REsidual plot instead of this style

# %% [markdown]
# ### This heatmap shows reconstruction error for endmember centroids under HMC sampling of the generative model:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#                             (a)
# ![image.png](attachment:image.png)

# %% [markdown]
#                             (b)
# ![image.png](attachment:image.png)

# %% [markdown]
# Mean absolute error for VI, MCMC, NFINDR:
#
# (0.49649847, 0.118429616, 0.5536023)
#
# Median absolute error for VI, MCMC, NFINDR:
#
# (0.6248209, 0.27590626, 0.63147795)

# %% [markdown]
# Runtime comparison
#
# * VI: 16 seconds (1600 iterations with Adam, learning rate = .005)
# * HMC: 5 minutes
# * N Finder: < 1 second

# %% [markdown]
# todos
#
# Adam hyperparameter scan
